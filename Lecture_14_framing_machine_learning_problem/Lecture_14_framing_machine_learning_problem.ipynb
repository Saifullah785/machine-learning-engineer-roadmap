# %% [markdown]
# # 📘 How to Frame a Machine Learning Problem | How to Plan a Data Science Project Effectively

# %% [markdown]
# # 🎯 Why It’s Important
#
#
# ---
#
#
# ## Framing the problem properly is like setting a destination in Google Maps.
#
#
# If you start building a model without understanding the problem, you're like a cab driver driving with no address. 🚕
#
#
# Most ML projects fail not because of poor models — but because the problem wasn’t framed properly from the start.

# %% [markdown]
# # ✅ 7-Step Framework to Frame a Machine Learning Problem
#
#
# ---
#
#
# ## Let’s break it down with examples.
#
# Think of it like planning a home renovation – clear goals, tools, steps, and timelines.

# %% [markdown]
# # 🔹 Step 1: Understand the Business Problem
#
#
# ---
#
#
#
# ## Question to Ask:
#
# 👉 What exactly are we trying to improve or predict?
#
# ## 🎯 Example:
#
# The restaurant owner says: “I want to reduce food wastage.”
#
# ## 📌 You define this as:
#
# "Predict how much of each ingredient will be needed daily."

# %% [markdown]
# # 🔹 Step 2: Convert it into a Machine Learning Problem
#
#
# ---
#
#
# ## Question to Ask:
# 👉 Can this be solved by learning from past data?
#
# ## 🎯 Example:
#
# Yes. You have past data: number of customers, day of the week, sales of each dish → So you can train a model to predict demand.
#
# ## 📌 Type of ML:
#
#  Supervised Learning → Regression (predict quantities)
#
#  Big picture ===>End product==>Prediction

# %% [markdown]
# # 🔹 Step 3: Define Inputs and Outputs
#
#
# ---
#
#
#
# ## Question to Ask:
#
# 👉 What data do we have? What do we want to predict?
#
# ## 🎯 Example:
#
# Input: Day, time, weather, past demand, promotions
#
#
# Output: Quantity of ingredients to prepare
#
#
# 📌 This helps you know what to collect and build features from.

# %% [markdown]
# # 🔹 Step 4: Collect and Prepare the Data
#
#
# ---
#
#
#
# ## Question to Ask:
#
# 👉 Is the data available, clean, and usable?
#
# ## 🎯 Example:
#
# Gather:
#
# e.g 1
#
# ==>1.watch time
#
# ==>2.Search but did not find
#
# ==>3.content left in the middle
#
# ==>4.clicked on recommendation(order of recommendations)
#
# e.g 2
#
# POS (point-of-sale) data
#
# Inventory logs
#
# Weather info
#
# ## 📌 You may need to do EDA (Exploratory Data Analysis) here:
#
# Check for missing values
#
# Remove outliers
#
# Visualize trends
#
# Feature engineering
#
# Like checking the quality of your ingredients before cooking. 🥦

# %% [markdown]
# # 🔹 Step 5: Select the Right ML Approach
#
#
# ---
#
#
# ## Question to Ask:
#
# 👉 What kind of ML task is this?
#
# ## 🎯 Examples:
#
# Is it classification (Yes/No, Spam/Not Spam)?
#
# Is it regression (Predict quantity)?
#
# Is it clustering (Group similar users)?
#
# Is it time series (predict over time)?
#
# ## 📌 Choose models accordingly:
#
#  Linear Regression, Decision Tree, Random Forest, etc.

# %% [markdown]
# # 🔹 Step 6: Train, Evaluate, and Validate Model
#
#
# ---
#
#
#
# ## Question to Ask:
#
# 👉 How well does the model perform?
#
# ## 🎯 Example:
#
# Train your model and test on unseen data.
#
# ## 📌 Use metrics like:
#
# MAE / RMSE (for regression)
#
# Accuracy / F1 Score (for classification)
#
# Like tasting food before serving to customers. 🍲

# %% [markdown]
# # 🔹 Step 7: Deploy and Monitor
#
#
# ---
#
#
#
# ## Question to Ask:
#
# 👉 Can this solution be used in real-time or daily operations?
#
# ## 🎯 Example:
#
# Once satisfied, deploy the model to predict daily ingredients needed.
#
# ## 📌 Set up:
#
# Automated pipeline
#
# Monitoring system
#
# Alerts if predictions are off
#
# Like installing a recipe board in the kitchen that updates daily.

# %% [markdown]
# # 📌 Summary Table: Problem Framing Checklist

# %% [markdown]
# ![problem framing checklist.png](data:image/png;base64,...)

# %% [markdown]
# # 🎁 Memory Hack – Think Like a Doctor 🩺

# %% [markdown]
# ![think like a doctor.png](data:image/png;base64,...)
