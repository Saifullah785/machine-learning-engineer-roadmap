# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifullah785/machine-learning-engineer-roadmap/blob/main/Lecture_64_Bagging_Ensemble_Classifiers_%26_Regression/Lecture_64_Part_03_Bagging_regressor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import necessary libraries for data manipulation, visualization, and machine learning.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the Boston Housing dataset from a CSV file into a pandas DataFrame.
df = pd.read_csv('/content/BostonHousing.csv')
# Display the entire DataFrame.
df
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
# Get the dimensions (number of rows and columns) of the DataFrame.
df.shape
# Out:
# (506, 14)

# %%
# Separate the features (X) and the target variable (y).
# 'medv' is the target variable (median value of owner-occupied homes).
x = df.drop('medv', axis=1)
y = df['medv']

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

# Import specific modules for different regression models, grid search for hyperparameter tuning,
# R-squared score for evaluation, and splitting data into training and testing sets.

# %%
# Split the data into training and testing sets.
# 80% of the data will be used for training and 20% for testing.
# random_state ensures reproducibility of the split.
X_train, X_test, Y_train, Y_test = train_test_split(x, y, train_size=0.80,test_size=0.2,random_state=123)
# Print the shapes of the resulting training and testing sets to verify the split.
print('Train/Test Sets Sizes : ')
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# Train/Test Sets Sizes :
# (404, 13)
# (102, 13)
# (404,)
# (102,)

# %%
# Initialize instances of different regression models.
lr = LinearRegression()
dt = DecisionTreeRegressor()
knn = KNeighborsRegressor()

# %%
# Train each of the initialized regression models on the training data.
lr.fit(X_train, Y_train)
dt.fit(X_train, Y_train)
knn.fit(X_train, Y_train)
# Out:
# KNeighborsRegressor()

# %%
# Make predictions on the test set using each trained model.
y_pred_lr = lr.predict(X_test)
y_pred_dt = dt.predict(X_test)
y_pred_knn = knn.predict(X_test)

# %%
# Calculate and print the R-squared score for each model's predictions on the test set.
# R-squared is a measure of how well the model fits the data.
print('R2 Score for Linear Regression : ', r2_score(Y_test, y_pred_lr))
print('R2 Score for Decision Tree Regression : ', r2_score(Y_test, y_pred_dt))
print('R2 Score for KNN Regression : ', r2_score(Y_test, y_pred_knn))
# Out:
# R2 Score for Linear Regression :  0.6592466510354096
# R2 Score for Decision Tree Regression :  0.43003280270005384
# R2 Score for KNN Regression :  0.5475962186976784

# %%
from sklearn.ensemble import BaggingRegressor

# Initialize a Bagging Regressor model with a specified random state for reproducibility.
bag_regressor = BaggingRegressor(random_state=1)
# Train the Bagging Regressor model on the training data.
bag_regressor.fit(X_train, Y_train)
# Out:
# BaggingRegressor(random_state=1)

# %%
# Make predictions on the test set using the trained Bagging Regressor model.
y_preds = bag_regressor.predict(X_test)

# Calculate and print the R-squared score for the Bagging Regressor on both the training and test sets.
print('Training Coefficient of R^2 :%.3f'%bag_regressor.score(X_train, Y_train))
print('Test Coefficient of R^2 :%.3f'%bag_regressor.score(X_test, Y_test))
# Out:
# Training Coefficient of R^2 :0.980
# Test Coefficient of R^2 :0.818

# %%
# %%time

# Get the number of samples and features from the DataFrame.
n_samples = df.shape[0]
n_features = df.shape[1]

# Define the parameter grid for GridSearchCV to tune the Bagging Regressor.
# This includes different base estimators, number of estimators, sample/feature sizes, and bootstrapping options.
params = {'estimator': [None, LinearRegression(), KNeighborsRegressor()],
          'n_estimators': [20,50,100],
          'max_samples':[0.5,1.0],
          'max_features':[0.5,1.0],
          'bootstrap': [True, False],
          'bootstrap_features': [True, False]}
# Out:
# CPU times: user 53 µs, sys: 2 µs, total: 55 µs
# Wall time: 59.8 µs

# %%
# Initialize GridSearchCV with the Bagging Regressor, the parameter grid, cross-validation folds, and parallel processing.
bagging_regressor_grid = GridSearchCV(BaggingRegressor(random_state=1, n_jobs=-1), param_grid = params, cv=3, n_jobs=-1, verbose=1)
# Fit the GridSearchCV to the training data to find the best parameters.
bagging_regressor_grid.fit(X_train, Y_train)
# Out:
# Fitting 3 folds for each of 144 candidates, totalling 432 fits
# GridSearchCV(cv=3, estimator=BaggingRegressor(n_jobs=-1, random_state=1),
#              n_jobs=-1,
#              param_grid={'bootstrap': [True, False],
#                          'bootstrap_features': [True, False],
#                          'estimator': [None, LinearRegression(),
#                                        KNeighborsRegressor()],
#                          'max_features': [0.5, 1.0], 'max_samples': [0.5, 1.0],
#                          'n_estimators': [20, 50, 100]},
#              verbose=1)

# %%
# Print the R-squared scores for the best estimator found by GridSearchCV on the training and test sets.
print('Train R^2 Score : %.3f'%bagging_regressor_grid.best_estimator_.score(X_train, Y_train))
print('Test R^2 Score : %.3f'%bagging_regressor_grid.best_estimator_.score(X_test, Y_test))
# Print the best cross-validation R-squared score found during the grid search.
print('Best R^2 Score Through Grid Search : %.3f'%bagging_regressor_grid.best_score_)
# Print the best parameters found by GridSearchCV.
print('Best Parameters : ',bagging_regressor_grid.best_params_)
# Out:
# Train R^2 Score : 0.983
# Test R^2 Score : 0.805
# Best R^2 Score Through Grid Search : 0.871
# Best Parameters :  {'bootstrap': True, 'bootstrap_features': False, 'estimator': None, 'max_features': 1.0, 'max_samples': 1.0, 'n_estimators': 50}
