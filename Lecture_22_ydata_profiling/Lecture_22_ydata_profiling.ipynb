# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifullah785/machine-learning-engineer-roadmap/blob/main/Lecture_22_ydata_profiling/Lecture_22_ydata_profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install ydata-profiling

# %%
# Import necessary libraries
import pandas as pd
from ydata_profiling import ProfileReport

# %%
# Load the training data
df = pd.read_csv('/content/train.csv')

# %%
# Display the shape of the DataFrame
df.shape
# Out:
# (891, 12)

# %%
# Generate and export a profiling report of the DataFrame
df = pd.read_csv('/content/train.csv')
profile = ProfileReport(df, title="My Data Report", explorative=True)
profile.to_file("report.html")
