# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifullah785/machine-learning-engineer-roadmap/blob/main/Lecture_19_understanding_your_data_in_machine_learning/Lecture_19_understanding_your_data_in_machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Understanding your data**
#
# # Asking Basic Questions to your Data
#
# 1.How big is the data?
#
# 2.How does the data looks like?
#
# 3.What is the data type of columns?
#
# 4.Are there any missing values?
#
# 5.How does the data looks mathematically?
#
# 6.Are there any duplicate values?
#
# 7.How is the Corelation between the columns?

# %% [markdown]
# # **1.How big is the data?**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/dphi-official/Datasets/master/titanic_data.csv')

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # **2.How does the data looks like?**

# %%
# df.head(3)
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 226          227         1       2                Mellors, Mr. William John
# 719          720         0       3             Johnson, Mr. Malkolm Joackim
# 811          812         0       3                        Lester, Mr. James
# 775          776         0       3  Myhrman, Mr. Pehr Fabian Oliver Malkolm
# 36            37         1       3                         Mamee, Mr. Hanna
#
#       Sex   Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 226  male  19.0      0      0  SW/PP 751  10.5000   NaN        S
# 719  male  33.0      0      0     347062   7.7750   NaN        S
# 811  male  39.0      0      0  A/4 48871  24.1500   NaN        S
# 775  male  18.0      0      0     347078   7.7500   NaN        S
# 36   male   NaN      0      0       2677   7.2292   NaN        C

# %% [markdown]
# # **3.What is the data type of columns?**

# %%
# Data types
print(df.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # **4.Are there any missing values?**

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Percentage of missing values
print((df.isnull().sum() / len(df)) * 100)
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Cabin          77.104377
# Embarked        0.224467
# dtype: float64

# %% [markdown]
# # **5.How does the data looks mathematically?**

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# # **6.Are there any duplicate values?**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# # **7.Categorical Feature Distribution**

# %%
df['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
sns.boxplot(x=df['Age']) # Example: Replace 'Age' with your desired column
plt.show()

# %%
print(df.columns)
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # **Time Trend Check**

# %%
# df['date_column'] = pd.to_datetime(df['date_column'])
# print(df['date_column'].min(), df['date_column'].max())

# %% [markdown]
# # **7.How is the Corelation between the columns?**

# %%
numerical_df = df.select_dtypes(include=['number'])  # Select only numerical columns
correlation_matrix = numerical_df.corr()
print(correlation_matrix)
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
correlation_matrix.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.118646 -0.058257  0.076158 -0.306772 -0.268503
# Survived       -0.118646  1.000000 -0.590758 -0.028323 -0.146368  0.018331
# Pclass         -0.058257 -0.590758  1.000000 -0.560316  0.191531  0.030697
# Age             0.076158 -0.028323 -0.560316  1.000000 -0.633254 -0.497296
# SibSp          -0.306772 -0.146368  0.191531 -0.633254  1.000000  0.646330
# Parch          -0.268503  0.018331  0.030697 -0.497296  0.646330  1.000000
# Fare           -0.119078  0.477350 -0.841633  0.200635  0.094765  0.213491
#
#                  Fare
# PassengerId -0.119078
# Survived     0.477350
# Pclass      -0.841633
# Age          0.200635
# SibSp        0.094765
# Parch        0.213491
# Fare         1.000000

# %%
correlation_matrix.corr()['Survived']
# Out:
# PassengerId   -0.118646
# Survived       1.000000
# Pclass        -0.590758
# Age           -0.028323
# SibSp         -0.146368
# Parch          0.018331
# Fare           0.477350
# Name: Survived, dtype: float64

# %% [markdown]
# Correlation tells us how strongly columns are related.
#
# Values near +1 = Strong Positive
#
# Values near -1 = Strong Negative
#
# Values near 0 = No relation

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix.corr(), annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# # **🧠 Quick Memory Recap Table**

# %% [markdown]
# # **Step    |   Task    |     Code**
#
# Size ===> df.shape
#
# View Sample ===> df.head()
#
# Data Types===> df.dtypes
#
# Missing Values ===>  df.isnull().sum()
#
# Duplicates===> df.duplicated().sum()
#
# Statistics===>  df.describe()
#
# Categorical Counts===>  df['col'].value_counts()
#
# Correlation ===> df.corr()
#
# Target Balance===>  df['target'].value_counts()
#
# Time Range ===> pd.to_datetime(df['date'])
