# %% [markdown]
# # 📘 AI vs ML vs DL – Complete, Easy & Practical Guide

# %% [markdown]
# 🔷 1. What is AI (Artificial Intelligence)?
#
# 📌 Definition:
#
# AI is a branch of computer science that makes machines think and act like humans.
#
# It’s the big umbrella. Under AI, we have ML and DL.
#
# ✅ AI = Any technique that enables machines to mimic human behavior.

# %% [markdown]
# # 🔍 Daily Life Examples of AI:
#
# 🧠 Voice assistants like Siri, Alexa (they understand and respond like humans)
#
#
# 🤖 Chatbots on websites (act like a customer support agent)
#
#
# 🧾 Scanning documents and extracting text (like humans reading)
#
#
# 🧹 Robotic vacuum cleaner deciding where to go (auto decisions)

# %% [markdown]
# # 🔷 2. What is ML (Machine Learning)?
#
# 📌 Definition:
#
# Machine Learning is a subset of AI where machines learn from data instead of being manually programmed.
#
# ✅ ML = AI that learns from examples (data)

# %% [markdown]
# # 🔍 Daily Life Examples of ML:
#
# 📧 Gmail detecting spam emails
#
#
# 🎵 Spotify recommending songs you like
#
#
# 🛒 Amazon showing "customers also bought" products
#
#
# 📸 Facebook tagging your friends in photos using face recognition
#
#
# 🧠 ML learns from past data to make future predictions

# %% [markdown]
# # 🔷 3. What is DL (Deep Learning)?
#
# 📌 Definition:
#
# Deep Learning is a subset of ML that uses neural networks, which are inspired by the human brain.
#
#
# It can automatically learn features from raw data — especially useful when data is huge and complex (like images, sound, video).
#
#
# ✅ DL = ML that uses brain-like models (neural networks) to learn patterns.

# %% [markdown]
# # 🔍 Daily Life Examples of DL:
#
# 🖼️ Face ID in your phone (deep learning on images)
#
#
# 🎙️ Voice recognition (Google Assistant, Siri)
#
#
# 🚗 Self-driving cars (detecting road, signs, people)
#
#
# 🧠 Medical diagnosis from X-rays/CT scans
#
#
# 🤯 DL shines in complex problems where traditional ML struggles.

# %% [markdown]
# # 🔁 Simple Analogy to Remember Forever
#
# Imagine:
#
# 🔹 AI = The goal
# I want a machine to think like a human.
#
#
# 🔸 ML = The path
# I’ll teach the machine using data and examples.
#
#
# 🔻 DL = The technique
#
# I’ll use brain-like networks (neural networks) to learn from lots of data.

# %% [markdown]
# # 🧠 Memory Hack Summary Table

# %% [markdown]
# ![2025-04-23_21-47-30.png](data:image/png;base64,...)

# %% [markdown]
# # 📌 Final One-Liner Summary
#
# AI is the goal,
#
# ML is the way to reach that goal,
#
# DL is the best tool when the data is large and complex.
